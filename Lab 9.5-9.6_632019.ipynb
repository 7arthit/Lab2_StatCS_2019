# %%
#9-5
import scipy.stats as st
import numpy as np

x=2.3
mu=3
sigma=0.5
z=(x-mu)/sigma
#prob=st.norm.pdf(x,mu,sigma)
#prob=st.norm.pdf(z)
prob=st.norm.cdf(x,mu,sigma)
print('P(X<=%.2f)=%.4f'%(x,prob))
z=(x-mu)/sigma
prob=st.norm.cdf(z)
print('P(Z<=%.2f)=%.4f'%(z,prob))
# Out:
# P(X<=2.30)=0.0808
# P(Z<=-1.40)=0.0808

# %%
import scipy.stats as st
import numpy as np
import matplotlib.pyplot as plt

mu = 5
variance = 4
sigma = np.sqrt(variance)
x = np.linspace(mu - 3*sigma,mu +3*sigma,100)
plt.figure(1,figsize=(3,2))
plt.plot(x, st.norm.pdf(x, mu, sigma))
plt.title('pdf')
plt.figure(2,figsize=(3,2))
plt.plot(x, st.norm.cdf(x, mu, sigma))
plt.title('cdf')
plt.show()

# %%
import scipy.stats as st
import numpy as np
import matplotlib.pyplot as plt
x = np.arange(-5,5,0.1)
y = st.t.pdf(x,5)
z = st.norm.pdf(x,0,1)
plt.figure(figsize=(4,3))
plt.plot(x,y,'r-' ,x,z, 'b-.')
plt.show()

# %%
import scipy.stats as st
import numpy as np
nu = np.arange(1,6)
x = nu
y = st.chi2.pdf(x,nu)

print('y=',y)
prob1 = st.chi2.cdf(2,nu)
print('prob1=',prob1)
prob2 = st.chi2.cdf(4,nu)
print('prob2=',prob2)

plt.figure(1,figsize=(3,2))
plt.plot(x, st.norm.pdf(x,y))
plt.title('pdf')

plt.figure(2,figsize=(3,2))
plt.plot(x, st.norm.cdf(x,y))
plt.title('cdf')
plt.show()
# Out:
# y= [0.24197072 0.18393972 0.15418033 0.13533528 0.12204152]
# prob1= [0.84270079 0.63212056 0.4275933  0.26424112 0.15085496]
# prob2= [0.95449974 0.86466472 0.73853587 0.59399415 0.45058405]
